# %% [markdown]
# # User-Defined Functions & Scoping

# %% [markdown]
# # Homework Exercises

# %% [markdown]
# ### 1) Create a Module in VS Code and Import It into jupyter notebook <br>
# <p><b>Module should have the following capabilities:</b><br><br>
# 1a) Has a function to calculate the square footage of a house <br>
#     <b>Reminder of Formula: Length X Width == Area</b><br>
#         <hr>
# 1b) Has a function to calculate the circumference of a circle 2 Pi r <br><br>
# <b>Program in Jupyter Notebook should take in user input and use imported functions to calculate a circle's circumference or a houses square footage</b>
# </p>

# %%
from utils import get_house_area, get_cirle_circumference

# 1a
print(get_house_area(9,5))  # Expected output: 45

print(get_cirle_circumference(5)) # Expected output: 31.415...
# Out:
# 45
# 31.41592653589793

# %% [markdown]
# ### 2) Build a Shopping Cart Function <br>
# <p><b>You can use either lists or dictionaries. The program should have the following capabilities:</b><br><br>
# 1) Takes in input <br>
# 2) Stores user input into a dictionary or list <br>
# 3) The User can add or delete items <br>
# 4) The User can see current shopping list <br>
# 5) The program Loops until user 'quits' <br>
# 6) Upon quiting the program, print out all items in the user's list <br>
# </p>

# %%
from IPython.display import clear_output

# Ask the user four bits of input: Do you want to : Show/Add/Delete or Quit?
main_menu_header="Main Menu \n\n"
add_item_menu="Type \'add\' to add an item."
delete_item_menu="Type \'delete\' to delete an item."
view_item_menu="Type \'view\' to all items."
quit_menu="Type \'quit\' to quit."
# This is for bringing the user back to the main menu
go_back_menu="Type \'back\' to go back to the main menu."

main_menu = f"{main_menu_header}\n {add_item_menu} \n {delete_item_menu} \n {view_item_menu} \n\n {go_back_menu} \n\n {quit_menu} \n\n"

shopping = True



# Exits loop if 'quit' is typed.
def try_to_quit(command):

        command=input("Are you sure you want to ? Type \'yes\' for yes. Type \'no\' for no.").strip().lower()
        match command:
            case "yes":
                print("Okay then. You've exited your cart. Have a nice day.")
                return "leave"
            case "quit":
                print("Okay then. You've exited your cart. Have a nice day.")
                return "leave"
            case "no":
                return "back"
            case _:
                print("I didn't quite get that")
                return "quit"


def add_item(shopping_cart):
    

    item=""
    price=""

    # ADDS ITEMS
    
    command = input("Type item to add:").strip()

    if check_menu_change_or_quit(command) != None or command == "add":
        return command
        
    item = command
    print(f"{command} was added to your cart.")

    # Adds amount. Checks if number first
    while True:
        command = input("How much did it cost?").strip()
        try: 
            x =float(command)
            price = round(x,2)
            if check_menu_change_or_quit(command) != None or command == "add":
                return command
            print(f"{item} was added to your cart. It cost ${price}")
            shopping_cart[item] = price
            
            return "add"
        except:
            if check_menu_change_or_quit(command) != None or command == "add":
                return command
            print("Type item price as a number:")



def view_items(shopping_cart):
    print("         Receipt           ")
    print("---------------------------")
    
    for item,amount in shopping_cart.items():
        print(item, amount)

    total = round(sum(shopping_cart.values()),2)
    print("      ----------------       ")
    print(f"Your total is ${total}")
    
    return "back"



def delete_items(shopping_cart):
    print("Enter an item to delete")

    command = input().strip().lower()

    item = command
    
    if check_menu_change_or_quit(command) != None:
        return check_menu_change_or_quit(command)

    if item in shopping_cart:
        del(shopping_cart[item])
        print(f"{item} was removed from your cart.")
    else:
        print(f"{item} was not in your cart.")    
    return "delete"

def check_menu_change_or_quit(command):
    match command:
        case "back":
            return command
        case "quit":
            return command
        case _:
            return None




# Main Shopping loop
def checkout():
    command = None

    cart={}
    while shopping:
        if command == "leave":
            break
        if command == 'back' or command == None:
            command = input(main_menu).lstrip().rstrip().lower()
        match command:
            case "quit":
                command = try_to_quit(command)
            case "add":
                command = add_item(cart)
            case "view":
                command = view_items(cart)
            case "delete":
                command = delete_items(cart)
            case _:
                print("I didn't quit get that.")
                command = None
    # prints final recipt
    dumby_variable=view_items()

checkout()
# Out:
# Main Menu
#
#
#  Type 'add' to add an item.
#  Type 'delete' to delete an item.
#  Type 'view' to all items.
#
#  Type 'back' to go back to the main menu.
#
#  Type 'quit' to quit.
#
# add
